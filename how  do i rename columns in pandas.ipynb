# %%
import pandas as pd

# %%
df=pd.read_csv('http://bit.ly/uforeports')

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.shape
# Out:
# (18241, 5)

# %%
df.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
df.rename(columns={'Colors Reported':'Colors_Reported','Shape Reported':'Shape_Reported'},inplace=True)

# %%
df.columns
# Out:
# Index(['City', 'Colors_Reported', 'Shape_Reported', 'State', 'Time'], dtype='object')

# %%
df.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
### Another way how to rename dataframe
df_cols=['city','color reported','shape reported','state','time']
df.columns=df_cols

# %%
df.head()
# Out:
#                    city color reported shape reported state             time
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00

# %%
# very import 
# when you have 100 of columns if i want to change it in space with underscore
df.columns
# Out:
# Index(['city', 'color reported', 'shape reported', 'state', 'time'], dtype='object')

# %%
df.columns=df.columns.str.replace(' ', '_')

# %%
df.head()
# Out:
#                    city color_reported shape_reported state             time
# 0                Ithaca            NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene            NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            NaN          LIGHT    NY  4/18/1933 19:00

# %%
dataset=pd.read_csv('mobile.csv')

# %%
dataset.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
dataset.columns=dataset.columns.str.replace('_','')

# %%
dataset.head()
# Out:
#    batterypower  blue  clockspeed  dualsim  fc  fourg  intmemory  mdep  \
# 0           842     0         2.2        0   1      0          7   0.6
# 1          1021     1         0.5        1   0      1         53   0.7
# 2           563     1         0.5        1   2      1         41   0.9
# 3           615     1         2.5        0   0      0         10   0.8
# 4          1821     1         1.2        0  13      1         44   0.6
#
#    mobilewt  ncores  ...  pxheight  pxwidth   ram  sch  scw  talktime  threeg  \
# 0       188       2  ...        20      756  2549    9    7        19       0
# 1       136       3  ...       905     1988  2631   17    3         7       1
# 2       145       5  ...      1263     1716  2603   11    2         9       1
# 3       131       6  ...      1216     1786  2769   16    8        11       1
# 4       141       2  ...      1208     1212  1411    8    2        15       1
#
#    touchscreen  wifi  pricerange
# 0            0     1           1
# ...
